# %% [markdown]
# # "A" sessile drop sitting on a superhydrophobic surface
#
# <img src="Schematic.png"
#         alt="Picture"
#         width="600"
#         style="display: block; margin: 0 auto" />
#
# Laplace equaiton for this problem gives a boundary value problem (see figure) where the two boundaries are the surface of the drop and the surface of the substrate. However, both boundaries are not known apriori. Therefore, we will solve the problem using the initial value problem (IVP) formulation.
#
# The set of ODE that we need to solve is the following:
#
# $$ \frac{d\phi}{ds} + \frac{\sin\phi}{r} = \kappa_T + Bo z $$
#
# where $r-z$ is the cylindrical coordinate system as shown in the figure. We have parameterized the equation for curvature using the length of arc $s$ and the tangent angle $\phi$. See page 15-16 of [deserno2004notes](https://www.cmu.edu/biolphys/deserno/pdf/diff_geom.pdf) for more details. Consequently, two more ODEs are needed to solve the problem:
#
# $$ \frac{dr}{ds} = \cos\phi $$
# $$ \frac{dz}{ds} = \sin\phi $$
#
# ### Initial conditions
#
# $$ \phi(s = 0) = 0 $$
# $$ r(s = 0) = 0 $$
#
# **Note:** Need to initialize with a very small (finite) valuen of $r(s = 0)$ to avoid division by zero.
#
# $$ z(s = 0) = 0 $$
#
# ### References
# ``` bib
# @misc{deserno2004notes,
#   title={Notes on differential geometry},
#   author={Deserno, M.},
#   year={2004},
#   publisher={Dover, New York. https://www.cmu.edu/biolphys/deserno/pdf/diff_geom.pdf}
# }
# ```
#
# *Note* Initial guess of $\kappa_T$: The initial guess for the curvature at the apex of the drop is taken from the database: [NormalizeBond.csv](NormalizeBond.csv). If such a file is absent, $\kappa_T = 2$ is taken as the initial guess.

# %% [markdown]
# ### Essential imports

# %%
from numpy import *
from scipy.integrate import solve_ivp
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import os
import pandas as pd
import sys

mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'

AxesLabel, TickLabel = [30, 30]
plt.rcParams.update({
    'font.size' : TickLabel,                   # Set font size to 11pt
    'axes.labelsize': AxesLabel,               # -> axis labels
    'legend.fontsize': AxesLabel,              # -> legends
    'xtick.labelsize': TickLabel,              # -> x-axis tick labels
    'ytick.labelsize': TickLabel,              # -> y-axis tick labels
})

# %% [markdown]
# ## Essential functions

# %% [markdown]
# ### Solution

# %%
# Laplace equation for a sessile drop
def LaplaceEqn(t, y, Bo, KappaT):
    Phi = y[0]
    r = y[1]
    z = y[2]

    f0 = Bo*z + KappaT - sin(Phi)/r
    f1 = cos(Phi)
    f2 = sin(Phi)

    return array([f0, f1, f2])

# stop integration when Phi = pi
def event(t, y, Bo, KappaT):
    return y[0] - 1.001*pi

# calculate the volume of the drop given by (R, Z)
def volume(R, Z):
    return -pi*trapz(R**2, Z)

# calculate the volume of the drop given by (R, Z)
def surface(R, Z, S):
    return 2*pi*trapz(R, S)

# calculate the center of mass of the drop given by (R, Z)
def centerOfMass(R, Z):
    return trapz((R**2)*Z, Z)/trapz(R**2, Z)

# main funtion to get the drop shape
def getDrop(Bo, KappaT):
  # Initial conditions
  Phi0, r0, z0 = 0.0, 1e-50, 0.0
  y0 = array([Phi0, r0, z0])
  y0.reshape(3,)

  # parameterizatio is done using the arc length s
  s0, sMax, ds = 0.0, 5*pi, 1e-6
  
  event.terminal = True
  return solve_ivp(LaplaceEqn, [s0, sMax], y0, args=(Bo, KappaT), t_eval=arange(s0, sMax, ds), events=event, rtol=1e-10, atol=1e-16)

# %% [markdown]
# ### Gradient descent algorithm to get the drop profile!

# %%
def CorrectDrop(Bo, CountMax, lr, KappaT):
      Error, VolError = [], 1.0
      count = 0
      while (abs(VolError) > 1.0e-10 and count < CountMax):
        print('------------------------------------')
        count += 1
        sol = getDrop(Bo, KappaT)
        S, Phi, r, z = sol.t, sol.y[0], sol.y[1], sol.y[2]
        # coordinate transformation to have drop straight up
        Z = -z+z[-1]
        R = r
        # join a straight line from the last point to the origin
        Z = append(Z, 0.0)
        R = append(R, 0.0)
        S = append(S, S[-1]+r[-1])
        r = append(r, 0.0)
        z = append(z, z[-1])
        Phi = append(Phi, pi)

        Vol = volume(R, Z)
        VolError = Vol - (4.0/3.0)*pi
        print('Volume = %4.3e and VolError = %4.3e' % (Vol, VolError))

        # use gradient descent to find the updated KappaT
        if KappaT < 1:
          KappaT = KappaT*(1.0 + lr*VolError)
        else:
          KappaT = KappaT + lr*VolError
        
        print('Done: Iteration = %d, Next KappaT = %5.4e' % (count, KappaT))
        Error.append(VolError)
        KappaTNew = KappaT

      print('------------------------------------')

      # if the volume did not converge, stop the code
      if abs(VolError) > 1.0e-6:
          print('Volume did not converge after %d iterations for Bond = %.15e. Stopping code. VolError = %4.3e' % (count, Bo, VolError))
          sys.exit(1)
      
      return R, Z, S, Phi, r, z, KappaTNew, Error

# %% [markdown]
# ### Function to run Basilisk to check the initial condition

# %%
def gettingFacets(L0, InitConditionFile):
    import subprocess as sp
    exe = ["./InitialCondition", str(L0), InitConditionFile]
    p = sp.Popen(exe, stdout=sp.PIPE, stderr=sp.PIPE)
    stdout, stderr = p.communicate()
    temp1 = stderr.decode("utf-8")
    temp2 = temp1.split("\n")
    segs = []
    skip = False
    if (len(temp2) > 1e2):
        for n1 in range(len(temp2)):
            temp3 = temp2[n1].split(" ")
            if temp3 == ['']:
                skip = False
                pass
            else:
                if not skip:
                    temp4 = temp2[n1+1].split(" ")
                    r1, z1 = array([float(temp3[1]), float(temp3[0])])
                    r2, z2 = array([float(temp4[1]), float(temp4[0])])
                    segs.append(((r1, z1),(r2,z2)))
                    skip = True
    return segs

# %% [markdown]
# ### Plotting

# %%
def Plotting(R, Z, S, Phi, r, z, filename, Bo, KappaT, Zcm, InterfaceBas, TestWithBasilisk):
    S = S/pi

    fig, AX = plt.subplots(2, 2)
    fig.patch.set_facecolor('white')
    fig.set_size_inches(20, 15)
    ax1, ax2, ax3, ax4 = AX.flatten()

    
    ax1.plot(R, Z, 'r-', linewidth=4.0)
    ax1.plot(-R, Z, 'r-', linewidth=4.0)
    if TestWithBasilisk:
        line_segments = LineCollection(InterfaceBas, linewidths=4, colors='#1a9641', linestyle='solid')
        ax1.add_collection(line_segments)

    ax1.plot(0, Zcm, 'bo', markersize=15.0)
    ax1.set_xlabel(r'$\mathcal{R}/R_0$')
    ax1.set_ylabel(r'$\mathcal{Z}/R_0$')
    if Bo<125:
        ax1.set_aspect('equal')
    else:
        ax1.set_box_aspect(1)
    ax1.set_xlim(-1.1*R.max(), 1.1*R.max())
    ax1.set_ylim(0.0, 1.05*Z.max())

    ax2.plot(S, Phi/pi, 'b-', linewidth=4.0)
    ax2.set_xlabel(r'$s/\left(\pi R_0\right)$')
    ax2.set_ylabel(r'$\phi/\pi$')
    ax2.set_box_aspect(1)
    ax2.set_xlim(0.0, S.max())
    ax2.set_ylim(0.0, 1.05)

    ax3.plot(S, r, 'k-')
    ax3.set_xlabel(r'$s/\left(\pi R_0\right)$')
    ax3.set_ylabel(r'$r/R_0$')
    ax3.set_box_aspect(1)
    ax3.set_xlim(0.0, S.max())
    ax3.set_ylim(0.0, 1.05*r.max())

    ax4.plot(S, z, 'k-')
    ax4.set_xlabel(r'$s/\left(\pi R_0\right)$')
    ax4.set_ylabel(r'$z/R_0$')
    ax4.set_box_aspect(1)
    ax4.set_xlim(0.0, S.max())
    ax4.set_ylim(0.0, 1.05*z.max())
    # set figure title
    l1, b1, w1, h1 = ax1.get_position().bounds
    l2, b2, w2, h2 = ax2.get_position().bounds

    L = max(b1+h1, b2+h2)
    # set title position
    fig.text(0.5, L+0.025, r'$Bo = %5.4e$, $\kappa_TR_0 = %5.4e$' % (Bo, KappaT), fontsize=AxesLabel, ha='center')

    plt.savefig(filename, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Main code

# %%
# Learning rate for the gradient descent algorithm and the maximum number of iterations, whether to plot the results, whether to plot error decay from the gradient descent, and the domain length for Basilisk code
lr, CountMax, Plot, PlotError, L0, TestWithBasilisk = 0.25, 500, True, True, 8.0, True
# TestWithBasilisk True needs a compiled Basilisk code in the same folder called InitialCondition.c. If you do not have this code, set TestWithBasilisk to False.

# Bond number is the input parameter. Use an array here to loop over multiple Bond numbers if needed. 
BondNumbers = array([1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3])

KappaTlist = zeros_like(BondNumbers)
Bond = zeros_like(BondNumbers)
Height = zeros_like(BondNumbers)
Zcm = zeros_like(BondNumbers)
Width = zeros_like(BondNumbers)
Rfoot = zeros_like(BondNumbers)
Perimeter = zeros_like(BondNumbers)
SurfaceArea = zeros_like(BondNumbers)

folder='TestingImages'
if not os.path.exists(folder):
    os.makedirs(folder)
TableFile='NormalizeBond.csv'
if os.path.exists(TableFile):
   df = pd.read_csv(TableFile)
   Table=True
   # df.head()
else:
   KappaGuess = 2.0
   Table=False

for Bo in BondNumbers:
  if Table:
     # find the index of the closest value to the input value
     idx = (abs(df['Bond'] - Bo)).argmin()
     # print(idx)
     KappaT = df['KappaTR0'][idx]
  else:
      KappaT = KappaGuess
  
  print("Initial guess for KappaT = ", KappaT)

  R, Z, S, Phi, r, z, KappaT, Error = CorrectDrop(Bo, CountMax, lr, KappaT)

  if PlotError:
       plt.plot(abs(array(Error)), 'k.')
       plt.xlabel('Iteration')
       plt.ylabel('Error')
       plt.yscale('log')
       plt.show()
  # Save some metrics
  Rfoot[where(BondNumbers==Bo)] = R[-2]
  # width and height of the drop
  Height[where(BondNumbers==Bo)] = Z.max()
  Width[where(BondNumbers==Bo)] = R.max()
  # center of mass
  Zcm[where(BondNumbers==Bo)] = centerOfMass(R, Z)
  # Volume of the drop
  Vol = volume(R, Z)
  Vol /= (4.0/3.0)*pi        
  # Perimeter of the drop
  Perimeter[where(BondNumbers==Bo)] = S[-1]
  # Surface area of the drop
  SurfaceArea[where(BondNumbers==Bo)] = surface(R, Z, S)
  KappaTlist[where(BondNumbers==Bo)] = KappaT

  # Print some metrics!
  print('------------------------------------')
  print('(3V)(4pi)^{-1} = %5.4e' % Vol)
  print('Perimeter = %5.4e' % Perimeter[where(BondNumbers==Bo)])
  print('Surface Area = %5.4e' % SurfaceArea[where(BondNumbers==Bo)])

  print('KappaT = %5.4e, Bo = %5.4e, H = %4.3f, Zcm = %4.3f, W = %4.3f, Rw = %4.3f' % (KappaT, Bo, float(Height[where(BondNumbers==Bo)]), float(Zcm[where(BondNumbers==Bo)]), float(Width[where(BondNumbers==Bo)]), float(Rfoot[where(BondNumbers==Bo)])))
  print('<------------------------------------>')

  if TestWithBasilisk:
     print('Doing Basilisk now for Bo = %5.4e' % Bo)
     Interface = pd.DataFrame({'x': Z, 'y': R})
     InitConditionFile='%s/InitialCondition_Bo%4.3f.dat' % (folder, Bo)
     Interface.to_csv(InitConditionFile, index=False, header=False, sep=' ')
     # Run Basilisk
     InterfaceBas = gettingFacets(L0, InitConditionFile)
     print('Done with Basilisk for Bo = %5.4e' % Bo)
  else:
     InterfaceBas = None
     
  if Plot:
    filename = '%s/Drops_Bond_%5.4f.pdf' % (folder, Bo)
    Plotting(R, Z, S, Phi, r, z, filename, Bo, KappaT, Zcm[where(BondNumbers==Bo)], InterfaceBas, TestWithBasilisk)
# Out:
# Initial guess for KappaT =  2.0006880225931503
# ------------------------------------
# Volume = 4.180e+00 and VolError = -8.496e-03
# Done: Iteration = 1, Next KappaT = 1.9986e+00
# ------------------------------------
# Volume = 4.194e+00 and VolError = 4.837e-03
# Done: Iteration = 2, Next KappaT = 1.9998e+00
# ------------------------------------
# Volume = 4.186e+00 and VolError = -2.761e-03
# Done: Iteration = 3, Next KappaT = 1.9991e+00
# ------------------------------------
# Volume = 4.190e+00 and VolError = 1.574e-03
# Done: Iteration = 4, Next KappaT = 1.9995e+00
# ------------------------------------
# Volume = 4.188e+00 and VolError = -8.977e-04
# Done: Iteration = 5, Next KappaT = 1.9993e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 5.119e-04
# Done: Iteration = 6, Next KappaT = 1.9994e+00
# ------------------------------------
# Volume = 4.188e+00 and VolError = -2.919e-04
# Done: Iteration = 7, Next KappaT = 1.9993e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.665e-04
# Done: Iteration = 8, Next KappaT = 1.9993e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -9.494e-05
# Done: Iteration = 9, Next KappaT = 1.9993e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError =
Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.754e-09
# Done: Iteration = 28, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -9.919e-10
# Done: Iteration = 29, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 5.611e-10
# Done: Iteration = 30, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -3.174e-10
# Done: Iteration = 31, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.795e-10
# Done: Iteration = 32, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.016e-10
# Done: Iteration = 33, Next KappaT = 1.9934e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 5.745e-11
# Done: Iteration = 34, Next KappaT = 1.9934e+00
# ------------------------------------
# ------------------------------------
# (3V)(4pi)^{-1} = 1.0000e+00
# Perimeter = 3.1371e+00
# Surface Area = 1.2567e+01
# KappaT = 1.9934e+00, Bo = 1.0000e-02, H = 1.979, Zcm = 0.982, W = 1.002, Rw = 0.080
# <------------------------------------>
# Doing Basilisk now for Bo = 1.0000e-02
# Done with Basilisk for Bo = 1.0000e-02
# Initial guess for KappaT =  1.937283687145742
# ------------------------------------
# Volume = 4.177e+00 and VolError = -1.176e-02
# Done: Iteration = 1, Next KappaT = 1.9343e+00
# ------------------------------------
# Volume = 4.195e+00 and VolError = 6.149e-03
# Done: Iteration = 2, Next KappaT = 1.9359e+00
# ------------------------------------
# Volume = 4.186e+00 and VolError = -3.229e-03
# Done: Iteration = 3, Next KappaT = 1.9351e+00
# ------------------------------------
# Volume = 4.190e+00 and VolError = 1.692e-03
# Done: Iteration = 4, Next KappaT = 1.9355e+00
# ------------------------------------
# Volume = 4.188e+00 and VolError = -8.875e-04
# Done: Iteration = 5, Next KappaT = 1.9353e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 4.653e-04
# Done: Iteration = 6, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.440e-04
# Done: Iteration = 7, Next KappaT = 1.9353e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.279e-04
# Done: Iteration = 8, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -6.709e-05
# Done: Iteration = 9, Next KappaT = 1.9353e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 3.518e-05
# Done: Iteration = 10, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.845e-05
# Done: Iteration = 11, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 9.673e-06
# Done: Iteration = 12, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -5.072e-06
# Done: Iteration = 13, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.659e-06
# Done: Iteration = 14, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.394e-06
# Done: Iteration = 15, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 7.308e-07
# Done: Iteration = 16, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -3.828e-07
# Done: Iteration = 17, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.008e-07
# Done: Iteration = 18, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.053e-07
# Done: Iteration = 19, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 5.525e-08
# Done: Iteration = 20, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.898e-08
# Done: Iteration = 21, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.520e-08
# Done: Iteration = 22, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -7.974e-09
# Done: Iteration = 23, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 4.183e-09
# Done: Iteration = 24, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.194e-09
# Done: Iteration = 25, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.151e-09
# Done: Iteration = 26, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -6.038e-10
# Done: Iteration = 27, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 3.167e-10
# Done: Iteration = 28, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.661e-10
# Done: Iteration = 29, Next KappaT = 1.9354e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 8.715e-11
# Done: Iteration = 30, Next KappaT = 1.9354e+00
# ------------------------------------
# ------------------------------------
# (3V)(4pi)^{-1} = 1.0000e+00
# Perimeter = 3.1097e+00
# Surface Area = 1.2585e+01
# KappaT = 1.9354e+00, Bo = 1.0000e-01, H = 1.869, Zcm = 0.895, W = 1.016, Rw = 0.249
# <------------------------------------>
# Doing Basilisk now for Bo = 1.0000e-01
# Done with Basilisk for Bo = 1.0000e-01
# Initial guess for KappaT =  1.4738400842449897
# ------------------------------------
# Volume = 4.171e+00 and VolError = -1.779e-02
# Done: Iteration = 1, Next KappaT = 1.4694e+00
# ------------------------------------
# Volume = 4.195e+00 and VolError = 6.116e-03
# Done: Iteration = 2, Next KappaT = 1.4709e+00
# ------------------------------------
# Volume = 4.187e+00 and VolError = -2.122e-03
# Done: Iteration = 3, Next KappaT = 1.4704e+00
# ------------------------------------
# Volume = 4.190e+00 and VolError = 7.340e-04
# Done: Iteration = 4, Next KappaT = 1.4706e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.542e-04
# Done: Iteration = 5, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 8.798e-05
# Done: Iteration = 6, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -3.045e-05
# Done: Iteration = 7, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.054e-05
# Done: Iteration = 8, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -3.650e-06
# Done: Iteration = 9, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.262e-06
# Done: Iteration = 10, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -4.336e-07
# Done: Iteration = 11, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.460e-07
# Done: Iteration = 12, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -5.067e-08
# Done: Iteration = 13, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.759e-08
# Done: Iteration = 14, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -6.098e-09
# Done: Iteration = 15, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.110e-09
# Done: Iteration = 16, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -7.336e-10
# Done: Iteration = 17, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.591e-10
# Done: Iteration = 18, Next KappaT = 1.4705e+00
# ------------------------------------
# Volume = 4.189e+00 and VolError = -9.660e-11
# Done: Iteration = 19, Next KappaT = 1.4705e+00
# ------------------------------------
# ------------------------------------
# (3V)(4pi)^{-1} = 1.0000e+00
# Perimeter = 3.0493e+00
# Surface Area = 1.3078e+01
# KappaT = 1.4705e+00, Bo = 1.0000e+00, H = 1.447, Zcm = 0.627, W = 1.124, Rw = 0.675
# <------------------------------------>
# Doing Basilisk now for Bo = 1.0000e+00
# Done with Basilisk for Bo = 1.0000e+00
# Initial guess for KappaT =  0.1232047737479391
# ------------------------------------
# Volume = 4.196e+00 and VolError = 7.323e-03
# Done: Iteration = 1, Next KappaT = 1.2343e-01
# ------------------------------------
# Volume = 4.192e+00 and VolError = 3.691e-03
# Done: Iteration = 2, Next KappaT = 1.2354e-01
# ------------------------------------
# Volume = 4.191e+00 and VolError = 1.860e-03
# Done: Iteration = 3, Next KappaT = 1.2360e-01
# ------------------------------------
# Volume = 4.190e+00 and VolError = 9.371e-04
# Done: Iteration = 4, Next KappaT = 1.2363e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 4.722e-04
# Done: Iteration = 5, Next KappaT = 1.2365e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.379e-04
# Done: Iteration = 6, Next KappaT = 1.2365e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.199e-04
# Done: Iteration = 7, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 6.041e-05
# Done: Iteration = 8, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 3.043e-05
# Done: Iteration = 9, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.532e-05
# Done: Iteration = 10, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 7.734e-06
# Done: Iteration = 11, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 3.884e-06
# Done: Iteration = 12, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.970e-06
# Done: Iteration = 13, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 9.892e-07
# Done: Iteration = 14, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 4.968e-07
# Done: Iteration = 15, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.495e-07
# Done: Iteration = 16, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.253e-07
# Done: Iteration = 17, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 6.291e-08
# Done: Iteration = 18, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 3.160e-08
# Done: Iteration = 19, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.587e-08
# Done: Iteration = 20, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 7.968e-09
# Done: Iteration = 21, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 4.002e-09
# Done: Iteration = 22, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.009e-09
# Done: Iteration = 23, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.009e-09
# Done: Iteration = 24, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 5.075e-10
# Done: Iteration = 25, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 2.545e-10
# Done: Iteration = 26, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 1.275e-10
# Done: Iteration = 27, Next KappaT = 1.2366e-01
# ------------------------------------
# Volume = 4.189e+00 and VolError = 6.379e-11
# Done: Iteration = 28, Next KappaT = 1.2366e-01
# ------------------------------------
# ------------------------------------
# (3V)(4pi)^{-1} = 1.0000e+00
# Perimeter = 3.4458e+00
# Surface Area = 1.8377e+01
# KappaT = 1.2366e-01, Bo = 1.0000e+01, H = 0.666, Zcm = 0.290, W = 1.567, Rw = 1.401
# <------------------------------------>
# Doing Basilisk now for Bo = 1.0000e+01
# Done with Basilisk for Bo = 1.0000e+01
# Initial guess for KappaT =  1.0357494187207507e-09
# ------------------------------------
# Volume = 3.957e+00 and VolError = -2.322e-01
# Done: Iteration = 1, Next KappaT = 9.7562e-10
# ------------------------------------
# Volume = 3.976e+00 and VolError = -2.130e-01
# Done: Iteration = 2, Next KappaT = 9.2367e-10
# ------------------------------------
# Volume = 3.993e+00 and VolError = -1.953e-01
# Done: Iteration = 3, Next KappaT = 8.7857e-10
# ------------------------------------
# Volume = 4.010e+00 and VolError = -1.791e-01
# Done: Iteration = 4, Next KappaT = 8.3923e-10
# ------------------------------------
# Volume = 4.024e+00 and VolError = -1.643e-01
# Done: Iteration = 5, Next KappaT = 8.0476e-10
# ------------------------------------
# Volume = 4.038e+00 and VolError = -1.507e-01
# Done: Iteration = 6, Next KappaT = 7.7444e-10
# ------------------------------------
# Volume = 4.051e+00 and VolError = -1.382e-01
# Done: Iteration = 7, Next KappaT = 7.4768e-10
# ------------------------------------
# Volume = 4.062e+00 and VolError = -1.268e-01
# Done: Iteration = 8, Next KappaT = 7.2399e-10
# ------------------------------------
# Volume = 4.073e+00 and VolError = -1.163e-01
# Done: Iteration = 9, Next KappaT = 7.0294e-10
# ------------------------------------
# Volume = 4.082e+00 and VolError = -1.066e-01
# Done: Iteration = 10, Next KappaT = 6.8420e-10
# ------------------------------------
# Volume = 4.091e+00 and VolError = -9.782e-02
# Done: Iteration = 11, Next KappaT = 6.6747e-10
# ------------------------------------
# Volume = 4.099e+00 and VolError = -8.972e-02
# Done: Iteration = 12, Next KappaT = 6.5250e-10
# ------------------------------------
# Volume = 4.106e+00 and VolError = -8.230e-02
# Done: Iteration = 13, Next KappaT = 6.3907e-10
# ------------------------------------
# Volume = 4.113e+00 and VolError = -7.549e-02
# Done: Iteration = 14, Next KappaT = 6.2701e-10
# ------------------------------------
# Volume = 4.120e+00 and VolError = -6.925e-02
# Done: Iteration = 15, Next KappaT = 6.1616e-10
# ------------------------------------
# Volume = 4.125e+00 and VolError = -6.352e-02
# Done: Iteration = 16, Next KappaT = 6.0637e-10
# ------------------------------------
# Volume = 4.131e+00 and VolError = -5.826e-02
# Done: Iteration = 17, Next KappaT = 5.9754e-10
# ------------------------------------
# Volume = 4.135e+00 and VolError = -5.344e-02
# Done: Iteration = 18, Next KappaT = 5.8956e-10
# ------------------------------------
# Volume = 4.140e+00 and VolError = -4.902e-02
# Done: Iteration = 19, Next KappaT = 5.8233e-10
# ------------------------------------
# Volume = 4.144e+00 and VolError = -4.497e-02
# Done: Iteration = 20, Next KappaT = 5.7578e-10
# ------------------------------------
# Volume = 4.148e+00 and VolError = -4.125e-02
# Done: Iteration = 21, Next KappaT = 5.6985e-10
# ------------------------------------
# Volume = 4.151e+00 and VolError = -3.784e-02
# Done: Iteration = 22, Next KappaT = 5.6446e-10
# ------------------------------------
# Volume = 4.154e+00 and VolError = -3.471e-02
# Done: Iteration = 23, Next KappaT = 5.5956e-10
# ------------------------------------
# Volume = 4.157e+00 and VolError = -3.184e-02
# Done: Iteration = 24, Next KappaT = 5.5510e-10
# ------------------------------------
# Volume = 4.160e+00 and VolError = -2.921e-02
# Done: Iteration = 25, Next KappaT = 5.5105e-10
# ------------------------------------
# Volume = 4.162e+00 and VolError = -2.679e-02
# Done: Iteration = 26, Next KappaT = 5.4736e-10
# ------------------------------------
# Volume = 4.164e+00 and VolError = -2.458e-02
# Done: Iteration = 27, Next KappaT = 5.4400e-10
# ------------------------------------
# Volume = 4.166e+00 and VolError = -2.254e-02
# Done: Iteration = 28, Next KappaT = 5.4093e-10
# ------------------------------------
# Volume = 4.168e+00 and VolError = -2.068e-02
# Done: Iteration = 29, Next KappaT = 5.3813e-10
# ------------------------------------
# Volume = 4.170e+00 and VolError = -1.897e-02
# Done: Iteration = 30, Next KappaT = 5.3558e-10
# ------------------------------------
# Volume = 4.171e+00 and VolError = -1.740e-02
# Done: Iteration = 31, Next KappaT = 5.3325e-10
# ------------------------------------
# Volume = 4.173e+00 and VolError = -1.596e-02
# Done: Iteration = 32, Next KappaT = 5.3112e-10
# ------------------------------------
# Volume = 4.174e+00 and VolError = -1.464e-02
# Done: Iteration = 33, Next KappaT = 5.2918e-10
# ------------------------------------
# Volume = 4.175e+00 and VolError = -1.343e-02
# Done: Iteration = 34, Next KappaT = 5.2740e-10
# ------------------------------------
# Volume = 4.176e+00 and VolError = -1.232e-02
# Done: Iteration = 35, Next KappaT = 5.2578e-10
# ------------------------------------
# Volume = 4.177e+00 and VolError = -1.130e-02
# Done: Iteration = 36, Next KappaT = 5.2429e-10
# ------------------------------------
# Volume = 4.178e+00 and VolError = -1.037e-02
# Done: Iteration = 37, Next KappaT = 5.2293e-10
# ------------------------------------
# Volume = 4.179e+00 and VolError = -9.513e-03
# Done: Iteration = 38, Next KappaT = 5.2169e-10
# ------------------------------------
# Volume = 4.180e+00 and VolError = -8.726e-03
# Done: Iteration = 39, Next KappaT = 5.2055e-10
# ------------------------------------
# Volume = 4.181e+00 and VolError = -8.005e-03
# Done: Iteration = 40, Next KappaT = 5.1951e-10
# ------------------------------------
# Volume = 4.181e+00 and VolError = -7.343e-03
# Done: Iteration = 41, Next KappaT = 5.1855e-10
# ------------------------------------
# Volume = 4.182e+00 and VolError = -6.736e-03
# Done: Iteration = 42, Next KappaT = 5.1768e-10
# ------------------------------------
# Volume = 4.183e+00 and VolError = -6.179e-03
# Done: Iteration = 43, Next KappaT = 5.1688e-10
# ------------------------------------
# Volume = 4.183e+00 and VolError = -5.669e-03
# Done: Iteration = 44, Next KappaT = 5.1615e-10
# ------------------------------------
# Volume = 4.184e+00 and VolError = -5.200e-03
# Done: Iteration = 45, Next KappaT = 5.1548e-10
# ------------------------------------
# Volume = 4.184e+00 and VolError = -4.770e-03
# Done: Iteration = 46, Next KappaT = 5.1486e-10
# ------------------------------------
# Volume = 4.184e+00 and VolError = -4.376e-03
# Done: Iteration = 47, Next KappaT = 5.1430e-10
# ------------------------------------
# Volume = 4.185e+00 and VolError = -4.014e-03
# Done: Iteration = 48, Next KappaT = 5.1378e-10
# ------------------------------------
# Volume = 4.185e+00 and VolError = -3.682e-03
# Done: Iteration = 49, Next KappaT = 5.1331e-10
# ------------------------------------
# Volume = 4.185e+00 and VolError = -3.378e-03
# Done: Iteration = 50, Next KappaT = 5.1288e-10
# ------------------------------------
# Volume = 4.186e+00 and VolError = -3.099e-03
# Done: Iteration = 51, Next KappaT = 5.1248e-10
# ------------------------------------
# Volume = 4.186e+00 and VolError = -2.843e-03
# Done: Iteration = 52, Next KappaT = 5.1211e-10
# ------------------------------------
# Volume = 4.186e+00 and VolError = -2.608e-03
# Done: Iteration = 53, Next KappaT = 5.1178e-10
# ------------------------------------
# Volume = 4.186e+00 and VolError = -2.392e-03
# Done: Iteration = 54, Next KappaT = 5.1147e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -2.194e-03
# Done: Iteration = 55, Next KappaT = 5.1119e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -2.013e-03
# Done: Iteration = 56, Next KappaT = 5.1094e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.847e-03
# Done: Iteration = 57, Next KappaT = 5.1070e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.694e-03
# Done: Iteration = 58, Next KappaT = 5.1048e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.554e-03
# Done: Iteration = 59, Next KappaT = 5.1029e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.426e-03
# Done: Iteration = 60, Next KappaT = 5.1010e-10
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.308e-03
# Done: Iteration = 61, Next KappaT = 5.0994e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -1.200e-03
# Done: Iteration = 62, Next KappaT = 5.0979e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -1.100e-03
# Done: Iteration = 63, Next KappaT = 5.0964e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -1.010e-03
# Done: Iteration = 64, Next KappaT = 5.0952e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -9.261e-04
# Done: Iteration = 65, Next KappaT = 5.0940e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -8.496e-04
# Done: Iteration = 66, Next KappaT = 5.0929e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -7.793e-04
# Done: Iteration = 67, Next KappaT = 5.0919e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -7.149e-04
# Done: Iteration = 68, Next KappaT = 5.0910e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -6.558e-04
# Done: Iteration = 69, Next KappaT = 5.0902e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -6.016e-04
# Done: Iteration = 70, Next KappaT = 5.0894e-10
# ------------------------------------
# Volume = 4.188e+00 and VolError = -5.519e-04
# Done: Iteration = 71, Next KappaT = 5.0887e-10
# ------------------------------------
# Done: Iteration = 38, Next KappaT = 2.1037e-31
# ------------------------------------
# Volume = 3.775e+00 and VolError = -4.140e-01
# Done: Iteration = 39, Next KappaT = 1.8860e-31
# ------------------------------------
# Volume = 3.782e+00 and VolError = -4.067e-01
# Done: Iteration = 40, Next KappaT = 1.6943e-31
# ------------------------------------
# Volume = 3.789e+00 and VolError = -3.995e-01
# Done: Iteration = 41, Next KappaT = 1.5251e-31
# ------------------------------------
# Volume = 3.796e+00 and VolError = -3.923e-01
# Done: Iteration = 42, Next KappaT = 1.3755e-31
# ------------------------------------
# Volume = 3.804e+00 and VolError = -3.852e-01
# Done: Iteration = 43, Next KappaT = 1.2430e-31
# ------------------------------------
# Volume = 3.811e+00 and VolError = -3.781e-01
# Done: Iteration = 44, Next KappaT = 1.1255e-31
# ------------------------------------
# Volume = 3.818e+00 and VolError = -3.711e-01
# Done: Iteration = 45, Next KappaT = 1.0211e-31
# ------------------------------------
# Volume = 3.825e+00 and VolError = -3.640e-01
# Done: Iteration = 46, Next KappaT = 9.2821e-32
# ------------------------------------
# Volume = 3.832e+00 and VolError = -3.571e-01
# Done: Iteration = 47, Next KappaT = 8.4535e-32
# ------------------------------------
# Volume = 3.839e+00 and VolError = -3.502e-01
# Done: Iteration = 48, Next KappaT = 7.7135e-32
# ------------------------------------
# Volume = 3.855e+00 and VolError = -3.336e-01
# Done: Iteration = 49, Next KappaT = 7.0702e-32
# ------------------------------------
# Volume = 3.915e+00 and VolError = -2.739e-01
# Done: Iteration = 50, Next KappaT = 6.5861e-32
# ------------------------------------
# Volume = 3.965e+00 and VolError = -2.240e-01
# Done: Iteration = 51, Next KappaT = 6.2173e-32
# ------------------------------------
# Volume = 4.006e+00 and VolError = -1.827e-01
# Done: Iteration = 52, Next KappaT = 5.9333e-32
# ------------------------------------
# Volume = 4.040e+00 and VolError = -1.487e-01
# Done: Iteration = 53, Next KappaT = 5.7128e-32
# ------------------------------------
# Volume = 4.068e+00 and VolError = -1.207e-01
# Done: Iteration = 54, Next KappaT = 5.5404e-32
# ------------------------------------
# Volume = 4.091e+00 and VolError = -9.786e-02
# Done: Iteration = 55, Next KappaT = 5.4048e-32
# ------------------------------------
# Volume = 4.110e+00 and VolError = -7.923e-02
# Done: Iteration = 56, Next KappaT = 5.2978e-32
# ------------------------------------
# Volume = 4.125e+00 and VolError = -6.408e-02
# Done: Iteration = 57, Next KappaT = 5.2129e-32
# ------------------------------------
# Volume = 4.137e+00 and VolError = -5.178e-02
# Done: Iteration = 58, Next KappaT = 5.1454e-32
# ------------------------------------
# Volume = 4.147e+00 and VolError = -4.181e-02
# Done: Iteration = 59, Next KappaT = 5.0917e-32
# ------------------------------------
# Volume = 4.155e+00 and VolError = -3.374e-02
# Done: Iteration = 60, Next KappaT = 5.0487e-32
# ------------------------------------
# Volume = 4.162e+00 and VolError = -2.722e-02
# Done: Iteration = 61, Next KappaT = 5.0143e-32
# ------------------------------------
# Volume = 4.167e+00 and VolError = -2.195e-02
# Done: Iteration = 62, Next KappaT = 4.9868e-32
# ------------------------------------
# Volume = 4.171e+00 and VolError = -1.769e-02
# Done: Iteration = 63, Next KappaT = 4.9648e-32
# ------------------------------------
# Volume = 4.175e+00 and VolError = -1.426e-02
# Done: Iteration = 64, Next KappaT = 4.9471e-32
# ------------------------------------
# Volume = 4.177e+00 and VolError = -1.149e-02
# Done: Iteration = 65, Next KappaT = 4.9329e-32
# ------------------------------------
# Volume = 4.180e+00 and VolError = -9.257e-03
# Done: Iteration = 66, Next KappaT = 4.9214e-32
# ------------------------------------
# Volume = 4.181e+00 and VolError = -7.457e-03
# Done: Iteration = 67, Next KappaT = 4.9123e-32
# ------------------------------------
# Volume = 4.183e+00 and VolError = -6.007e-03
# Done: Iteration = 68, Next KappaT = 4.9049e-32
# ------------------------------------
# Volume = 4.184e+00 and VolError = -4.838e-03
# Done: Iteration = 69, Next KappaT = 4.8990e-32
# ------------------------------------
# Volume = 4.185e+00 and VolError = -3.896e-03
# Done: Iteration = 70, Next KappaT = 4.8942e-32
# ------------------------------------
# Volume = 4.186e+00 and VolError = -3.138e-03
# Done: Iteration = 71, Next KappaT = 4.8904e-32
# ------------------------------------
# Volume = 4.186e+00 and VolError = -2.527e-03
# Done: Iteration = 72, Next KappaT = 4.8873e-32
# ------------------------------------
# Volume = 4.187e+00 and VolError = -2.035e-03
# Done: Iteration = 73, Next KappaT = 4.8848e-32
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.638e-03
# Done: Iteration = 74, Next KappaT = 4.8828e-32
# ------------------------------------
# Volume = 4.187e+00 and VolError = -1.319e-03
# Done: Iteration = 75, Next KappaT = 4.8812e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -1.062e-03
# Done: Iteration = 76, Next KappaT = 4.8799e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -8.552e-04
# Done: Iteration = 77, Next KappaT = 4.8788e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -6.886e-04
# Done: Iteration = 78, Next KappaT = 4.8780e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -5.545e-04
# Done: Iteration = 79, Next KappaT = 4.8773e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -4.464e-04
# Done: Iteration = 80, Next KappaT = 4.8768e-32
# ------------------------------------
# Volume = 4.188e+00 and VolError = -3.595e-04
# Done: Iteration = 81, Next KappaT = 4.8763e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.894e-04
# Done: Iteration = 82, Next KappaT = 4.8760e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -2.330e-04
# Done: Iteration = 83, Next KappaT = 4.8757e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.876e-04
# Done: Iteration = 84, Next KappaT = 4.8755e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.511e-04
# Done: Iteration = 85, Next KappaT = 4.8753e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -1.216e-04
# Done: Iteration = 86, Next KappaT = 4.8751e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -9.791e-05
# Done: Iteration = 87, Next KappaT = 4.8750e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -7.894e-05
# Done: Iteration = 88, Next KappaT = 4.8749e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -6.347e-05
# Done: Iteration = 89, Next KappaT = 4.8748e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError = -5.115e-05
# Done: Iteration = 90, Next KappaT = 4.8748e-32
# ------------------------------------
# Volume = 4.189e+00 and VolError =