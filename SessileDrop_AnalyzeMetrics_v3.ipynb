# %% [markdown]
# ## Header
#
# Same as [SessileDrop_AnalyzeMetrics_v2.ipynb](SessileDrop_AnalyzeMetrics_v2.ipynb), but with the data sorting done properly.
#
# * The code [SessileDrop_WithBasilisk.ipynb](SessileDrop_WithBasilisk.ipynb) is good for $Bo > 1e-2$.
# * The code [SessileDrop_LowBondScaling.py](SessileDrop_LowBondScaling.py) is good for $Bo < 1e-2$ but computationally very expensive for any $Bo > 1e-2$.

# %% [markdown]
# # Analyze results
#
# There are several metrics:
#
# * Curvature at the top of the drop: $\kappa_T$
# * Height of the drop: $H$
# * Center of mass location of the drop $Z_{CM}$. Also compute the center of mass sag: $\delta$: it can be computed as $1-Z_{CM}/R_0$ or $2-H/R_0$
# * Width of the drop: $W$ (note that in the file NormalizeBond/NormalizeBond.csv, half of the width is stored)
# * Footprint of the drop: $R_{foot}$
# * Taylor Deformation: $D_T$
# * Perimeter of the drop: $P$
# * Area of the drop: $A$
#
# <img src="Schematic_Metrics.png"
#         alt="Picture"
#         width="600"
#         style="display: block; margin: 0 auto" />
#
#
# ### Word of caution
#
# Sometimes it is useful to normalize everything with the gravito-capillary length.
#
# Consequently, following conversions are also important:
#
# $$ \kappa_TR_0 = \tilde{\kappa_T}\sqrt{Bo} $$
#
# $$ L_i/R_0 = \tilde{L_i}/\sqrt{Bo} $$
#
# where $L_i$ are the different length scale metrics.

# %%
from numpy import *
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import matplotlib.cm as cm

mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'

AxesLabel, TickLabel = [30, 30]
plt.rcParams.update({
    'font.size' : TickLabel,                   # Set font size to 11pt
    'axes.labelsize': AxesLabel,               # -> axis labels
    'legend.fontsize': AxesLabel,              # -> legends
    'xtick.labelsize': TickLabel,              # -> x-axis tick labels
    'ytick.labelsize': TickLabel,              # -> y-axis tick labels
})

# %% [markdown]
# ### Read data

# %%
DiffColor = False
# both NormalizedR0_LowBond and NormalizeBond have data normalized by R0!

#df1
df = pd.read_csv('NormalizedR0_Data_v2.csv')
df = df.sort_values(by=['Bond'])
df.head()
# remove data where 'Height' is 0
df = df[df['Height'] != 0]
df = df[df['Bond'] >= 0.01]
# data normalized by R0
KappaTR0, Bond, HbyR0, ZcmbyR0, WbyR0, RWbyR0, PbyR0, AbyR02 = df['KappaT'], df['Bond'], df['Height'], df['Zcm'], df['Width'], df['Rfoot'], df['Perimeter'], df['SurfaceArea']
# data normalized by gravito-capillary length
KappaT, Bond, Height, Zcm, Width, Rfoot, P, A = df['KappaT']/Bond**(0.5), df['Bond'], df['Height']*Bond**(0.5), df['Zcm']*Bond**(0.5), df['Width']*Bond**(0.5), df['Rfoot']*Bond**(0.5), df['Perimeter']*Bond**(0.5), df['SurfaceArea']*Bond

df1 = pd.DataFrame({'Bond':Bond, 'KappaT':KappaT, 'Height':Height, 'Zcm':Zcm, 'Width':Width, 'Rfoot':Rfoot, 'Perimeter':P, 'SurfaceArea':A, 'KappaTR0':KappaTR0, 'HbyR0':HbyR0, 'ZcmbyR0':ZcmbyR0, 'WbyR0':WbyR0, 'RWbyR0':RWbyR0, 'PbyR0':PbyR0, 'AbyR02':AbyR02})
df1.name = 'df1'

#df2
df = pd.read_csv('NormalizedR0_Data_v2_LowBond.csv')
df = df.sort_values(by=['Bond'])
df.head()
# remove data where 'Height' is 0
df = df[df['Height'] != 0]
df = df[df['Bond'] >= 0.01]
# data normalized by R0
KappaTR0, Bond, HbyR0, ZcmbyR0, WbyR0, RWbyR0, PbyR0, AbyR02 = df['KappaT'], df['Bond'], df['Height'], df['Zcm'], df['Width'], df['Rfoot'], df['Perimeter'], df['SurfaceArea']
# data normalized by gravito-capillary length
KappaT, Bond, Height, Zcm, Width, Rfoot, P, A = df['KappaT']/Bond**(0.5), df['Bond'], df['Height']*Bond**(0.5), df['Zcm']*Bond**(0.5), df['Width']*Bond**(0.5), df['Rfoot']*Bond**(0.5), df['Perimeter']*Bond**(0.5), df['SurfaceArea']*Bond

df2 = pd.DataFrame({'Bond':Bond, 'KappaT':KappaT, 'Height':Height, 'Zcm':Zcm, 'Width':Width, 'Rfoot':Rfoot, 'Perimeter':P, 'SurfaceArea':A, 'KappaTR0':KappaTR0, 'HbyR0':HbyR0, 'ZcmbyR0':ZcmbyR0, 'WbyR0':WbyR0, 'RWbyR0':RWbyR0, 'PbyR0':PbyR0, 'AbyR02':AbyR02})
df2.name = 'df2'


#df3
df = pd.read_csv('NormalizedR0_Data_v2_LowBond_NoInitialGuess.csv')
df = df.sort_values(by=['Bond'])
df.head()
# remove data where 'Height' is 0
df = df[df['Height'] != 0]
df = df[df['Bond'] >= 0.01]
# data normalized by R0
KappaTR0, Bond, HbyR0, ZcmbyR0, WbyR0, RWbyR0, PbyR0, AbyR02 = df['KappaT'], df['Bond'], df['Height'], df['Zcm'], df['Width'], df['Rfoot'], df['Perimeter'], df['SurfaceArea']
# data normalized by gravito-capillary length
KappaT, Bond, Height, Zcm, Width, Rfoot, P, A = df['KappaT']/Bond**(0.5), df['Bond'], df['Height']*Bond**(0.5), df['Zcm']*Bond**(0.5), df['Width']*Bond**(0.5), df['Rfoot']*Bond**(0.5), df['Perimeter']*Bond**(0.5), df['SurfaceArea']*Bond

df3 = pd.DataFrame({'Bond':Bond, 'KappaT':KappaT, 'Height':Height, 'Zcm':Zcm, 'Width':Width, 'Rfoot':Rfoot, 'Perimeter':P, 'SurfaceArea':A, 'KappaTR0':KappaTR0, 'HbyR0':HbyR0, 'ZcmbyR0':ZcmbyR0, 'WbyR0':WbyR0, 'RWbyR0':RWbyR0, 'PbyR0':PbyR0, 'AbyR02':AbyR02})
df3.name = 'df3'

#df4
df = pd.read_csv('NormalizeBond.csv')
df = df.sort_values(by=['Bond'])
df.head()
# remove data where 'Height' is 0
df = df[df['HbyR0'] != 0]
# remove data where 'Bond' is less than 1
df = df[df['Bond'] >= 1]
# data normalized by R0
KappaTR0, Bond, HbyR0, ZcmbyR0, WbyR0, RWbyR0, PbyR0, AbyR02 = df['KappaTR0'], df['Bond'], df['HbyR0'], df['ZcmbyR0'], df['WbyR0'], df['RWbyR0'], df['PbyR0'], df['AbyR02']
# data normalized by gravito-capillary length
KappaT, Bond, Height, Zcm, Width, Rfoot, P, A = df['KappaTR0']/Bond**(0.5), df['Bond'], df['HbyR0']*Bond**(0.5), df['ZcmbyR0']*Bond**(0.5), df['WbyR0']*Bond**(0.5), df['RWbyR0']*Bond**(0.5), df['PbyR0']*Bond**(0.5), df['AbyR02']*Bond

df4 = pd.DataFrame({'Bond':Bond, 'KappaT':KappaT, 'Height':Height, 'Zcm':Zcm, 'Width':Width, 'Rfoot':Rfoot, 'Perimeter':P, 'SurfaceArea':A, 'KappaTR0':KappaTR0, 'HbyR0':HbyR0, 'ZcmbyR0':ZcmbyR0, 'WbyR0':WbyR0, 'RWbyR0':RWbyR0, 'PbyR0':PbyR0, 'AbyR02':AbyR02})
df4.name = 'df4'

#df5 -- good for Bo < 1e-2
df = pd.read_csv('NormalizedR0_Data_v3.csv')
df = df.sort_values(by=['Bond'])
df.head()
# remove data where 'Height' is 0
df = df[df['Height'] != 0]
# data normalized by R0
KappaTR0, Bond, HbyR0, ZcmbyR0, WbyR0, RWbyR0, PbyR0, AbyR02 = df['KappaT'], df['Bond'], df['Height'], df['Zcm'], df['Width'], df['Rfoot'], df['Perimeter'], df['SurfaceArea']
# data normalized by gravito-capillary length
KappaT, Bond, Height, Zcm, Width, Rfoot, P, A = df['KappaT']/Bond**(0.5), df['Bond'], df['Height']*Bond**(0.5), df['Zcm']*Bond**(0.5), df['Width']*Bond**(0.5), df['Rfoot']*Bond**(0.5), df['Perimeter']*Bond**(0.5), df['SurfaceArea']*Bond

df5 = pd.DataFrame({'Bond':Bond, 'KappaT':KappaT, 'Height':Height, 'Zcm':Zcm, 'Width':Width, 'Rfoot':Rfoot, 'Perimeter':P, 'SurfaceArea':A, 'KappaTR0':KappaTR0, 'HbyR0':HbyR0, 'ZcmbyR0':ZcmbyR0, 'WbyR0':WbyR0, 'RWbyR0':RWbyR0, 'PbyR0':PbyR0, 'AbyR02':AbyR02})
df5.name = 'df5'

# combine all dataframes
DF=[df1, df2, df3, df4, df5]

# find the length of DF
length = len(DF)
cmap = cm.get_cmap('YlGn', length)

Color = pd.DataFrame()
for i in range(length):
    if DiffColor:
        temp = pd.DataFrame({'name':DF[i].name, 'color':[cmap(i)]})
        Color = pd.concat([Color, temp], ignore_index=True)
    else:
        temp = pd.DataFrame({'name':DF[i].name, 'color':['k']})
        Color = pd.concat([Color, temp], ignore_index=True)

# del df
del df
# combine all dataframes into one dataframe
df = pd.concat(DF, ignore_index=True)
# write out df to csv
df.to_csv('SessileDropMetrics.csv', index=False)

# %%
Bomin1, Bomin2, Bomax1, Bomax2 = 1e-8, 1e-3, 1e4, 1e3
Bond = 10**linspace(log10(Bomin1), log10(Bomax1), 1000)

# %% [markdown]
# ## Curvature at the top of the drop: $\kappa_T$ vs Bond number $Bo$

# %%
fig, AX = plt.subplots(2, 2, figsize=(18, 18))
ax1, ax2, ax3, ax4 = AX[0, 0], AX[0, 1], AX[1, 0], AX[1, 1]

ax=ax1
for df in DF:
    ax.plot(df['Bond'], df['KappaT'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.set_box_aspect(1)
ax.set_ylim([1e-32, 1e5])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\kappa_T\sqrt{\gamma/\rho g}$')

ax=ax2
for df in DF:
    ax.plot(df['Bond'], df['KappaTR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 2*Bond**0, 'r--', label=r'$\kappa_TR_0 = 2$', linewidth=2)
# ax.plot(Bond, 1e14*Bond**(-12), 'b--', label=r'$\kappa_T = 2$', linewidth=2)
ax.set_box_aspect(1)
ax.set_ylim([1e-30, 10])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\kappa_TR_0$')
ax.legend(loc='best', fontsize=20)

ax=ax3
for df in DF:
    ax.plot(df['Bond'], df['KappaT'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.set_box_aspect(1)
ax.set_ylim([1e-30, 1e2])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\kappa_T\sqrt{\gamma/\rho g}$')

ax=ax4
for df in DF:
    ax.plot(df['Bond'], df['KappaTR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 2*Bond**0, 'r--', label=r'$\kappa_TR_0 = 2$', linewidth=2)
# ax.plot(Bond, 1e4*Bond**(-5), 'b--', label=r'$\kappa_T = 2$', linewidth=2)
ax.set_box_aspect(1)
ax.set_ylim([1e-32, 2.5])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\kappa_TR_0$')
ax.legend(loc='lower left', fontsize=20)

# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the curvature at the top of the drop with Bond number', fontsize=AxesLabel, ha='center')
plt.savefig('Metrics/0_KappaTvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Height of the drop: $H$ vs Bond number $Bo$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

ax=ax1
for df in DF:
    ax.plot(df['Bond'], df['Height'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 2*(Bond**0.5), 'r--', label=r'$H = 2R_0$')
ax.plot(Bond, 2/(Bond**0.0), 'b--', label=r'$H = 2\sqrt{\gamma/\rho g}$')
ax.set_box_aspect(1)
ax.set_ylim([1e-4, 3])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$H/\sqrt{\gamma/\rho g}$')
ax.legend(loc='lower right')

ax=ax2
for df in DF:
    ax.plot(df['Bond'], df['HbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 2*(Bond**0.0), 'r--', label=r'$H = 2R_0$')
ax.plot(Bond, 2/(Bond**0.5), 'b--', label=r'$H = 2\sqrt{\gamma/\rho g}$')
ax.set_box_aspect(1)
ax.set_ylim([0.01, 2.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$H/R_0$')
ax.legend(loc='lower left')


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the height of the drop with Bond number', fontsize=AxesLabel, ha='center')
plt.savefig('Metrics/1_HeightvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Center of mass location of the drop $Z_{COM}$ vs Bond number $Bo$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

ax=ax1
for df in DF:
    ax.plot(df['Bond'], df['Zcm'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, (Bond**0.5), 'r--', label=r'$Z_{CM} = R_0$')
ax.plot(Bond, 1/(Bond**0.0), 'b--', label=r'$Z_{CM} = \sqrt{\gamma/\rho g}$')
ax.set_box_aspect(1)
ax.set_ylim([7e-5, 1.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$Z_{CM}/\sqrt{\gamma/\rho g}$')
ax.legend(loc='lower right')

ax=ax2
for df in DF:
    ax.plot(df['Bond'], df['ZcmbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, (Bond**0.0), 'r--', label=r'$Z_{CM} = R_0$')
ax.plot(Bond, 1/(Bond**0.5), 'b--', label=r'$Z_{CM} = \sqrt{\gamma/\rho g}$')
ax.set_box_aspect(1)
ax.set_ylim([0.01, 1.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$Z_{CM}/R_0$')
ax.legend(loc='lower left')


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the height of the center of mass of the drop with Bond number', fontsize=AxesLabel, ha='center')
plt.savefig('Metrics/2_HeightCOMvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Center of mass sag $\delta$ vs Bond number $Bo$

# %%
fig, AX = plt.subplots(2, 2, figsize=(18, 16))
ax1, ax2, ax3, ax4 = AX.flatten()

ax=ax1
for df in DF:
    ax.plot(df['Bond'], 1-df['ZcmbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond[Bond<0.1]
ax.plot(Bo1, 0.1*Bo1, 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, (Bond**0.0), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (Bo/3)*abs(log(exp(5/6)*Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-8, 3])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\delta/R_0 = 1-Z_{CM}/R_0$')
ax.legend(loc='lower right', fontsize=15)

ax=ax2
for df in DF:
    ax.plot(df['Bond'], 2-df['HbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond[Bond<0.1]
ax.plot(Bo1, 0.1*Bo1, 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, 2*(Bond**0.0), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (Bo/3)*abs(log(Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-8, 3])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$2-H/R_0$')
ax.legend(loc='lower right', fontsize=15)

ax=ax3
for df in DF:
    ax.plot(df['Bond'], 1-df['ZcmbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond[Bond<0.75]
ax.plot(Bo1, 0.1*Bo1, 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, (Bond**0.0), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (Bo/3)*abs(log(exp(5/6)*Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-3, 1.1])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$\delta/R_0 = 1-Z_{CM}/R_0$')
ax.legend(loc='lower right', fontsize=15)

ax=ax4
for df in DF:
    ax.plot(df['Bond'], 2-df['HbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond[Bond<0.75]
ax.plot(Bo1, 0.1*Bo1, 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, 2*(Bond**0.0), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (Bo/3)*abs(log(Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-3, 2.1])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$2-H/R_0$')
ax.legend(loc='lower right', fontsize=15)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the center of mass sag of the drop with Bond number', fontsize=20, ha='center')
plt.savefig('Metrics/2_SagCOMvsBond_v3.pdf', bbox_inches='tight')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

ax=ax1
for df in DF:
    ax.plot(df['Bond'], (1-df['ZcmbyR0'])/df['Bond'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond
ax.plot(Bo1, (1/3)*(Bo1**0.0), 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, (Bond**(-1.0)), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (1/3)*abs(log(exp(5/6)*Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)


ax.set_box_aspect(1)
ax.set_ylim([5e-4, 10.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$(1-Z_{CM}/R_0)/Bo$')
ax.legend(loc='lower left', fontsize=15)

ax=ax2
for df in DF:
    ax.plot(df['Bond'], (2-df['HbyR0'])/df['Bond'], '*', color=Color[Color['name']==df.name]['color'].values[0])

Bo1 = Bond
ax.plot(Bo1, (1/3)*(Bo1**0.0), 'r--', label=r'$\delta \sim R_0Bo$: David Quere book', linewidth=4)
ax.plot(Bond, 2*(Bond**(-1.0)), 'g--', label=r'$Z_{CM} \to 0$', linewidth=4)

Bo = Bond[Bond<1]
y = (1/3)*abs(log(Bo/6))
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([5e-4, 10.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$(2-H/R_0)/Bo$')
ax.legend(loc='lower left', fontsize=15)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the center of mass sag of the drop with Bond number', fontsize=20, ha='center')
plt.savefig('Metrics/2_SagCOMvsBond_compensated_v3.pdf', bbox_inches='tight')

# %% [markdown]
# Compensated plot does not look good.

# %% [markdown]
# ## Half-width of the drop: $W$ vs Bond number $Bo$

# %%
fig, AX = plt.subplots(2, 3, figsize=(26, 15))
ax1, ax2, ax3, ax4, ax5, ax6 = AX.flatten()

ax=ax1
for df in DF:
    ax.plot(df['Bond'], df['Width'], '*', color=Color[Color['name']==df.name]['color'].values[0])

ax.plot(Bond, (Bond**0.5), 'r--', label=r'$W \sim R_0$',linewidth=3)
ax.plot(Bond, 0.8*(Bond**0.75), 'b--', label=r'$W \sim RBo^{1/4}$',linewidth=3)
ax.set_box_aspect(1)
ax.set_ylim([1e-5, 1e3])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/\sqrt{\gamma/\rho g}$')
ax.legend(loc='upper left',fontsize=15)

ax=ax2
for df in DF:
    ax.plot(df['Bond'], df['WbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])

ax.plot(Bond, (Bond**0.0), 'r--', label=r'$W \sim R_0$',linewidth=3)
# ax.plot(Bond, 1+0.12*(Bond**0.5), 'b--', label=r'$W \sim \sqrt{\gamma/\rho g}$')
ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$W \sim RBo^{1/4}$',linewidth=3)
ax.set_box_aspect(1)
ax.set_ylim([0.9, 9])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/R_0$')
ax.legend(loc='upper left',fontsize=15)
from matplotlib.ticker import StrMethodFormatter, NullFormatter
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
ax.yaxis.set_minor_formatter(StrMethodFormatter('{x:.0f}'))

ax=ax3
for df in DF:
    ax.plot(df['Bond'], df['WbyR0']-1, '*', color=Color[Color['name']==df.name]['color'].values[0])

ax.plot(Bond, 0.25*(Bond), 'r--', label=r'$W-R_0 \sim R_0Bo$')
ax.plot(Bond, 0.35*(Bond**(1/3)), 'g--', label=r'$W/R_0 - 1 \sim Bo^{1/3}$',linewidth=3)
ax.plot(Bond, 0.5*(Bond**(1/4)), 'b--', label=r'$W/R_0 - 1 \sim Bo^{1/4}$',linewidth=3)
# ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$W \sim RBo^{1/4}$')
ax.set_box_aspect(1)
ax.set_ylim([1e-9, 8])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/R_0-1$')
ax.legend(loc='lower right',fontsize=15)

ax=ax4
for df in DF:
    ax.plot(df['Bond'], df['Width'], '*', color=Color[Color['name']==df.name]['color'].values[0])
    
ax.plot(Bond, (Bond**0.5), 'r--', label=r'$W \sim R_0$',linewidth=3)
ax.plot(Bond, 0.8*(Bond**0.75), 'b--', label=r'$W \sim RBo^{1/4}$',linewidth=3)
ax.set_box_aspect(1)
ax.set_ylim([1e-3, 1e3])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/\sqrt{\gamma/\rho g}$')
ax.legend(loc='upper left',fontsize=15)

ax=ax5
for df in DF:
    ax.plot(df['Bond'], df['WbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, (Bond**0.0), 'r--', label=r'$W \sim R_0$',linewidth=3)
# ax.plot(Bond, 1+0.12*(Bond**0.5), 'b--', label=r'$W \sim \sqrt{\gamma/\rho g}$')
ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$W \sim RBo^{1/4}$',linewidth=3)
ax.set_box_aspect(1)
ax.set_ylim([0.9, 8])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/R_0$')
ax.legend(loc='upper left',fontsize=15)
from matplotlib.ticker import StrMethodFormatter, NullFormatter
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
ax.yaxis.set_minor_formatter(StrMethodFormatter('{x:.0f}'))

ax=ax6
for df in DF:
    ax.plot(df['Bond'], df['WbyR0']-1, '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 0.25*(Bond), 'r--', label=r'$W-R_0 \sim R_0Bo$')
ax.plot(Bond, 0.35*(Bond**(1/3)), 'g--', label=r'$W/R_0 - 1 \sim Bo^{1/3}$',linewidth=3)
ax.plot(Bond, 0.5*(Bond**(1/4)), 'b--', label=r'$W/R_0 - 1 \sim Bo^{1/4}$',linewidth=3)
# ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$W \sim RBo^{1/4}$')
ax.set_box_aspect(1)
ax.set_ylim([1e-5, 8])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$W/R_0-1$')
ax.legend(loc='lower right',fontsize=15)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Width of the drop with Bond number', fontsize=AxesLabel, ha='center')
plt.savefig('Metrics/3_WidthvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Footprint of the drop: $R_{foot}$ vs Bond number $Bo$

# %%
fig, Ax = plt.subplots(2, 2, figsize=(18, 18))
ax1, ax2, ax3, ax4 = Ax.flatten()

ax=ax1
for df in DF:
    ax.plot(df['Bond'], df['Rfoot'], '*', color=Color[Color['name']==df.name]['color'].values[0])  
ax.plot(Bond, 0.75*(Bond), 'r--', label=r'$R_{foot} \sim R_0\sqrt{Bo}$')
ax.plot(Bond, 0.8*(Bond**0.75), 'b--', label=r'$R_{foot} \sim R_0Bo^{3/4}$')

Bo = Bond[Bond<1]
y = (((2/3)*Bo)**0.5)*(Bo**0.5)
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-10, 1e3])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$R_{foot}/\sqrt{\gamma/\rho g}$')
ax.legend(loc='lower right',fontsize=20)

ax=ax2
for df in DF:
    ax.plot(df['Bond'], df['RWbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 0.75*(Bond**0.5), 'r--', label=r'$R_{foot} \sim R_0\sqrt{Bo}$')
ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$R_{foot} \sim R_0Bo^{1/4}$')

Bo = Bond[Bond<1]
y = (((2/3)*Bo)**0.5)
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-6, 1e1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$R_{foot}/R_0$')
ax.legend(loc='lower right', fontsize=20)

ax=ax3
for df in DF:
    ax.plot(df['Bond'], df['Rfoot'], '*', color=Color[Color['name']==df.name]['color'].values[0])  
ax.plot(Bond, 0.75*(Bond), 'r--', label=r'$R_{foot} \sim R_0\sqrt{Bo}$')
ax.plot(Bond, 0.8*(Bond**0.75), 'b--', label=r'$R_{foot} \sim R_0Bo^{3/4}$')

Bo = Bond[Bond<1]
y = (((2/3)*Bo)**0.5)*(Bo**0.5)
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-4, 200])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$R_{foot}/\sqrt{\gamma/\rho g}$')
ax.legend(loc='lower right',fontsize=20)

ax=ax4
for df in DF:
    ax.plot(df['Bond'], df['RWbyR0'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot(Bond, 0.75*(Bond**0.5), 'r--', label=r'$R_{foot} \sim R_0\sqrt{Bo}$')
ax.plot(Bond, 0.8*(Bond**0.25), 'b--', label=r'$R_{foot} \sim R_0Bo^{1/4}$')

Bo = Bond[Bond<1]
y = (((2/3)*Bo)**0.5)
ax.plot(Bo, y, 'b--', label=r'Chevy et al. (2012), $Bo \to 0$', linewidth=4)

ax.set_box_aspect(1)
ax.set_ylim([1e-2, 1e1])
ax.set_xlim([Bomin2, Bomax2])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$R_{foot}/R_0$')
ax.legend(loc='lower right', fontsize=20)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the foot print radius of the drop with Bond number', fontsize=AxesLabel, ha='center')
plt.savefig('Metrics/4_FootprintvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Taylor deformation: $D_T$ vs Bond number $Bo$

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10, 10))

ax=ax1

for df in DF:
    df['DT'] = (1 - df['Height']/(2*df['Width']))/(1 + df['Height']/(2*df['Width']))
    ax.plot(df['Bond'], df['DT'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.plot([Bond.min(), 1e6], [1, 1], 'r--', label=r'$D_T = 1$')
ax.set_box_aspect(1)
ax.set_ylim([0.0, 1.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$D_T = \frac{1-H/(2W)}{1+H/(2W)}$')
ax.legend(loc='best')
ax.set_title(r'Taylor deformation')
plt.savefig('Metrics/5_TaylorDeformationvsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Perimeter: $P$ vs Bond number $Bo$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

ax=ax1
ax.plot(Bond, pi*Bond**0.5, 'r--', label=r'$P \sim \pi R_0$', linewidth=4)
ax.plot(Bond, 0.5*pi*(Bond**(3/4)), 'b--', label=r'$P \sim \pi R_0Bo^{1/4}$', linewidth=4)

for df in DF:
    ax.plot(df['Bond'], df['Perimeter'], '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.set_box_aspect(1)
ax.set_ylim([1e-4, 1e4]) #P.max()*1.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$P/\sqrt{\gamma/\rho R_0}$')
ax.legend(loc='upper left', fontsize=20)

ax=ax2
ax.plot(Bond, Bond**0, 'r--', label=r'$P \sim \pi R_0$', linewidth=4)
ax.plot(Bond, 0.5*(Bond**(1/4)), 'b--', label=r'$P \sim \pi R_0Bo^{1/4}$', linewidth=4)
for df in DF:
    ax.plot(df['Bond'], df['PbyR0']/pi, '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.set_box_aspect(1)
ax.set_ylim([0.95, 4.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$P/(\pi R_0)$')
ax.legend(loc='upper left', fontsize=20)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the perimeter of the drop with Bond number', fontsize=20, ha='center')
plt.savefig('Metrics/6_PerimetervsBond_v3.pdf', bbox_inches='tight')

# %% [markdown]
# ## Surface Area: $A$ vs Bond number $Bo$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

ax=ax1
ax.plot(Bond, (4*pi)*Bond, 'r--', label=r'$A \sim 4 \pi R_0^2$', linewidth=4)
# ax.plot(Bond, 0.7*(4*pi)*(Bond**(4/3)), 'b--', label=r'$A \sim 4 \pi R_0^2Bo^{1/3}$', linewidth=4)
for df in DF:
    ax.plot(df['Bond'], df['SurfaceArea'], '*', color=Color[Color['name']==df.name]['color'].values[0])

ax.set_box_aspect(1)
ax.set_ylim([1e-8, 1e8]) #P.max()*1.1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$A/\left(\gamma/\rho R_0\right)$')
ax.legend(loc='upper left', fontsize=20)

ax=ax2
ax.plot(Bond, Bond**0, 'r--', label=r'$A \sim 4 \pi R_0^2$', linewidth=4)
# ax.plot(Bond, 0.7*(Bond**(1/3)), 'b--', label=r'$A \sim 4 \pi R_0^2Bo^{1/3}$', linewidth=4)
for df in DF:
    ax.plot(df['Bond'], df['AbyR02']/(4*pi), '*', color=Color[Color['name']==df.name]['color'].values[0])
ax.set_box_aspect(1)
ax.set_ylim([0.95, 2e1])
ax.set_xlim([Bomin1, Bomax1])
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$Bo$')
ax.set_ylabel(r'$A/(4\pi R_0^2)$')
ax.legend(loc='upper left', fontsize=20)


# set figure title
l1, b1, w1, h1 = ax1.get_position().bounds
l2, b2, w2, h2 = ax2.get_position().bounds

L = max(b1+h1, b2+h2)
# set title position
fig.text(0.5, L+0.025, r'Variation of the surface area of the drop with Bond number', fontsize=20, ha='center')
plt.savefig('Metrics/7_AreavsBond_v3.pdf', bbox_inches='tight')
